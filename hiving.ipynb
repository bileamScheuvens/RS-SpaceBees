# %%
import scipy.spatial as sl
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
points = np.genfromtxt('cache/actually_looks_good_2src.csv',delimiter=',')

# %%
plt.figure()
plt.scatter(points[:,0],points[:,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
vor = sl.Voronoi(points)

# %%
fig = sl.voronoi_plot_2d(vor)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
